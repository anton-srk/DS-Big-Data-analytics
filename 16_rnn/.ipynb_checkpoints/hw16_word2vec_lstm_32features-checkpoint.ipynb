# %% [markdown]
# # HW 16: NLP+LSTM. 32 features

# %%
import re
import logging
import time

from bs4 import BeautifulSoup
from gensim.models import Word2Vec
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier
from tqdm import tqdm_notebook

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Dense,
    Embedding,
    LSTM,
    GRU,
    SpatialDropout1D
)
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.datasets import imdb
from sklearn.metrics import roc_auc_score
from tensorflow.keras.utils import get_file
import pickle
from tqdm.notebook import tqdm

# %%
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)

# %%
def plot_history(history):
    history_dict = history.history
    loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']
    epochs = range(1, len(loss_values) + 1)


    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

    ax1.plot(epochs, loss_values, 'bo',
             label='Training loss')
    ax1.plot(epochs, val_loss_values, 'b',
             label='Validation loss')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.set_xscale('log')

    acc_values = history_dict['accuracy']
    val_acc_values = history_dict['val_accuracy']

    ax2.plot(epochs, acc_values, 'bo',
             label='Training acc')
    ax2.plot(epochs, val_acc_values, 'b',
             label='Validation acc')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Accuracy')
    ax2.set_xscale('log')


    plt.legend()
    plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %load_ext pycodestyle_magic

# %%
logging.basicConfig(format='%(asctime)s :\
                    %(levelname)s : %(message)s', level=logging.INFO)
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /home/anton/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/anton/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Import data

# %% [markdown]
# Getting the keras imdb dataset and converting it back to actual words

# %%
imdb = tf.keras.datasets.imdb
(train_data, train_labels), (test_data, test_labels) =\
    imdb.load_data(num_words=10000)

word_index = imdb.get_word_index()
reverse_word_index = dict([(value, key) for
                           (key, value) in word_index.items()])

# %%
train_reviews = [' '.join([reverse_word_index.get(i-3, "?")
                           for i in t]) for t in tqdm(train_data)]
# Out:
# HBox(children=(IntProgress(value=0, max=25000), HTML(value='')))

# %%
test_reviews = [' '.join([reverse_word_index.get(i-3, "?")
                          for i in t]) for t in tqdm(test_data)]
# Out:
# HBox(children=(IntProgress(value=0, max=25000), HTML(value='')))

# %%
train_data = pd.DataFrame(np.array(train_reviews),
                          columns=['review'], index=range(len(train_reviews)))
train_data['sentiment'] = train_labels
train_data.head()
# Out:
#                                               review  sentiment
# 0  ? this film was just brilliant casting locatio...          1
# 1  ? big hair big boobs bad music and a giant saf...          0
# 2  ? this has to be one of the worst films of the...          0
# 3  ? the ? ? at storytelling the traditional sort...          1
# 4  ? worst mistake of my life br br i picked this...          0

# %%
test_data = pd.DataFrame(np.array(test_reviews),
                         columns=['review'])
test_data['sentiment'] = test_labels
test_data.head()
# Out:
#                                               review  sentiment
# 0  ? please give this one a miss br br ? ? and th...          0
# 1  ? this film requires a lot of patience because...          1
# 2  ? many animation buffs consider ? ? the great ...          1
# 3  ? i generally love this type of movie however ...          0
# 4  ? like some other people wrote i'm a die hard ...          1

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
wordnet_lemmatizer = WordNetLemmatizer()

# %% [markdown]
# ### Helper functions

# %%
def series_to_wordlist(series, remove_stopwords=False):

    train_text0 = series.apply(lambda text:
                               BeautifulSoup(text, 'html.parser').get_text())
    train_text0 = train_text0.str.replace("[^a-zA-Z]", " ").str.lower()
    train_words = train_text0.str.split()

    if remove_stopwords:
        stops = set(stopwords.words("english"))
        train_words = train_words.apply(lambda text:
                                        [wordnet_lemmatizer.lemmatize(t, 'v')
                                         for t in text if t not in stops])
    else:
        train_words = train_words.apply(lambda text:
                                        [wordnet_lemmatizer.lemmatize(t, 'v')
                                         for t in text])

    return train_words.values.ravel()

# %%
def series_to_sentences(series, remove_stopwords=False):

    train_text = series.apply(lambda text:
                              BeautifulSoup(text, 'html.parser').get_text())
    train_tokenize = train_text.str.strip().apply(tokenizer.tokenize)

    tt_df = pd.DataFrame(train_tokenize.values.tolist())
    tt_df = tt_df.replace("[^a-zA-Z]", " ", regex=True)
    tt_df = tt_df.applymap(lambda x: x.lower() if pd.notnull(x) else '')
    stops = set(stopwords.words("english"))

    if remove_stopwords:
        tt_df = tt_df.applymap(lambda x: [wordnet_lemmatizer.lemmatize(t, 'v')
                                          for t in x.split()
                                          if t not in stops])
    else:
        tt_df = tt_df.applymap(lambda x: [wordnet_lemmatizer.lemmatize(t, 'v')
                                          for t in x.split()])

    idx = [x != [] for x in tt_df.values.ravel()]
    return tt_df.values.ravel()[idx]

# %%
# %%time
print('Parsing sentences from training set')
sentences = series_to_sentences(train_data['review'])
# Out:
# Parsing sentences from training set
# CPU times: user 1min 7s, sys: 797 ms, total: 1min 8s
# Wall time: 1min 8s

# %%
all_sentences = sentences

# %%
print(all_sentences[0])
# Out:
# ['this', 'film', 'be', 'just', 'brilliant', 'cast', 'location', 'scenery', 'story', 'direction', 'everyone', 's', 'really', 'suit', 'the', 'part', 'they', 'play', 'and', 'you', 'could', 'just', 'imagine', 'be', 'there', 'robert']

# %% [markdown]
# ### Defining the Word2Vec parameters

# %%
num_features = 32                  
min_word_count = 40        
num_workers = 8
context = 10                                                                                   
downsampling = 1e-4

# %% [markdown]
# Training the model

# %%
# Initialize and train the model (this will take some time)
print("Training model...")
model = Word2Vec(
    all_sentences,
    workers=8,
    size=num_features,
    min_count=min_word_count,
    window=context,
    sample=downsampling,
    seed=42
)
# Out:
# 2019-12-05 14:26:37,703 :                    INFO : collecting all words and their counts
# 2019-12-05 14:26:37,703 :                    INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-12-05 14:26:37,746 :                    INFO : PROGRESS: at sentence #10000, processed 166536 words, keeping 6492 word types
# 2019-12-05 14:26:37,779 :                    INFO : PROGRESS: at sentence #20000, processed 342739 words, keeping 7289 word types
# 2019-12-05 14:26:37,816 :                    INFO : PROGRESS: at sentence #30000, processed 508010 words, keeping 7545 word types
# 2019-12-05 14:26:37,857 :                    INFO : PROGRESS: at sentence #40000, processed 682510 words, keeping 7632 word types
# Training model...
# 2019-12-05 14:26:37,891 :                    INFO : PROGRESS: at sentence #50000, processed 856794 words, keeping 7666 word types
# 2019-12-05 14:26:37,936 :                    INFO : PROGRESS: at sentence #60000, processed 1030291 words, keeping 7680 word types
# 2019-12-05 14:26:37,979 :                    INFO : PROGRESS: at sentence #70000, processed 1201078 words, keeping 7685 word types
# 2019-12-05 14:26:38,018 :                    INFO : PROGRESS: at sentence #80000, processed 1376792 words, keeping 7686 word types
# 2019-12-05 14:26:38,049 :                    INFO : PROGRESS: at sentence #90000, processed 1550921 words, keeping 7687 word types
# 2019-12-05 14:26:38,092 :                    INFO : PROGRESS: at sentence #100000, processed 1718983 words, keeping 7687 word types
# 2019-12-05 14:26:38,133 :                    INFO : PROGRESS: at sentence #110000, processed 1893836 words, keeping 7687 word types
# 2019-12-05 14:26:38,174 :                    INFO : PROGRESS: at sentence #120000, processed 2069544 words, keeping 7687 word types
# 2019-12-05 14:26:38,217 :                    INFO : PROGRESS: at sentence #130000, processed 2244569 words, keeping 7687 word types
# 2019-12-05 14:26:38,254 :                    INFO : PROGRESS: at sentence #140000, processed 2419031 words, keeping 7687 word types
# 2019-12-05 14:26:38,297 :                    INFO : PROGRESS: at sentence #150000, processed 2593119 words, keeping 7687 word types
# 2019-12-05 14:26:38,340 :                    INFO : PROGRESS: at sentence #160000, processed 2770608 words, keeping 7689 word types
# 2019-12-05 14:26:38,382 :                    INFO : PROGRESS: at sentence #170000, processed 2948298 words, keeping 7689 word types
# 2019-12-05 14:26:38,428 :                    INFO : PROGRESS: at sentence #180000, processed 3119850 words, keeping 7689 word types
# 2019-12-05 14:26:38,466 :                    INFO : PROGRESS: at sentence #190000, processed 3290858 words, keeping 7689 word types
# 2019-12-05 14:26:38,501 :                    INFO : PROGRESS: at sentence #200000, processed 3469573 words, keeping 7689 word types
# 2019-12-05 14:26:38,548 :                    INFO : PROGRESS: at sentence #210000, processed 3646583 words, keeping 7689 word types
# 2019-12-05 14:26:38,588 :                    INFO : PROGRESS: at sentence #220000, processed 3822996 words, keeping 7689 word types
# 2019-12-05 14:26:38,629 :                    INFO : PROGRESS: at sentence #230000, processed 3998987 words, keeping 7689 word types
# 2019-12-05 14:26:38,672 :                    INFO : PROGRESS: at sentence #240000, processed 4170662 words, keeping 7689 word types
# 2019-12-05 14:26:38,712 :                    INFO : PROGRESS: at sentence #250000, processed 4339066 words, keeping 7689 word types
# 2019-12-05 14:26:38,756 :                    INFO : PROGRESS: at sentence #260000, processed 4516163 words, keeping 7689 word types
# 2019-12-05 14:26:38,795 :                    INFO : PROGRESS: at sentence #270000, processed 4688763 words, keeping 7689 word types
# 2019-12-05 14:26:38,833 :                    INFO : PROGRESS: at sentence #280000, processed 4857734 words, keeping 7689 word types
# 2019-12-05 14:26:38,873 :                    INFO : PROGRESS: at sentence #290000, processed 5033020 words, keeping 7689 word types
# 2019-12-05 14:26:38,917 :                    INFO : PROGRESS: at sentence #300000, processed 5211555 words, keeping 7689 word types
# 2019-12-05 14:26:38,952 :                    INFO : PROGRESS: at sentence #310000, processed 5388739 words, keeping 7689 word types
# 2019-12-05 14:26:38,988 :                    INFO : PROGRESS: at sentence #320000, processed 5561026 words, keeping 7689 word types
# 2019-12-05 14:26:39,010 :                    INFO : collected 7689 word types from a corpus of 5661152 raw words and 325662 sentences
# 2019-12-05 14:26:39,010 :                    INFO : Loading a fresh vocabulary
# 2019-12-05 14:26:39,023 :                    INFO : effective_min_count=40 retains 6506 unique words (84% of original 7689, drops 1183)
# 2019-12-05 14:26:39,024 :                    INFO : effective_min_count=40 leaves 5619744 word corpus (99% of original 5661152, drops 41408)
# 2019-12-05 14:26:39,047 :                    INFO : deleting the raw counts dictionary of 7689 items
# 2019-12-05 14:26:39,047 :                    INFO : sample=0.0001 downsamples 448 most-common words
# 2019-12-05 14:26:39,048 :                    INFO : downsampling leaves estimated 2322594 word corpus (41.3% of prior 5619744)
# 2019-12-05 14:26:39,065 :                    INFO : estimated required memory for 6506 words and 32 dimensions: 4918536 bytes
# 2019-12-05 14:26:39,066 :                    INFO : resetting layer weights
# 2019-12-05 14:26:39,146 :                    INFO : training model with 8 workers on 6506 vocabulary and 32 features, using sg=0 hs=0 sample=0.0001 negative=5 window=10
# 2019-12-05 14:26:40,156 :                    INFO : EPOCH 1 - PROGRESS: at 39.40% examples, 909146 words/s, in_qsize 15, out_qsize 0
# 2019-12-05 14:26:41,157 :                    INFO : EPOCH 1 - PROGRESS: at 80.38% examples, 931687 words/s, in_qsize 14, out_qsize 1
# 2019-12-05 14:26:41,602 :                    INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-12-05 14:26:41,605 :                    INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-12-05 14:26:41,608 :                    INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-12-05 14:26:41,610 :                    INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-12-05 14:26:41,613 :                    INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-12-05 14:26:41,617 :                    INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-05 14:26:41,620 :                    INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-05 14:26:41,626 :                    INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-05 14:26:41,627 :                    INFO : EPOCH - 1 : training on 5661152 raw words (2322270 effective words) took 2.5s, 939349 effective words/s
# 2019-12-05 14:26:42,642 :                    INFO : EPOCH 2 - PROGRESS: at 39.93% examples, 921663 words/s, in_qsize 16, out_qsize 0
# 2019-12-05 14:26:43,652 :                    INFO : EPOCH 2 - PROGRESS: at 80.73% examples, 932364 words/s, in_qsize 13, out_qsize 2
# 2019-12-05 14:26:44,068 :                    INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-12-05 14:26:44,078 :                    INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-12-05 14:26:44,083 :                    INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-12-05 14:26:44,085 :                    INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-12-05 14:26:44,087 :                    INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-12-05 14:26:44,088 :                    INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-05 14:26:44,089 :                    INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-05 14:26:44,093 :                    INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-05 14:26:44,093 :                    INFO : EPOCH - 2 : training on 5661152 raw words (2323314 effective words) took 2.5s, 947356 effective words/s
# 2019-12-05 14:26:45,116 :                    INFO : EPOCH 3 - PROGRESS: at 40.78% examples, 932496 words/s, in_qsize 15, out_qsize 0
# 2019-12-05 14:26:46,117 :                    INFO : EPOCH 3 - PROGRESS: at 79.37% examples, 915114 words/s, in_qsize 14, out_qsize 1
# 2019-12-05 14:26:46,583 :                    INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-12-05 14:26:46,584 :                    INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-12-05 14:26:46,590 :                    INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-12-05 14:26:46,595 :                    INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-12-05 14:26:46,596 :                    INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-12-05 14:26:46,596 :                    INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-05 14:26:46,598 :                    INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-05 14:26:46,600 :                    INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-05 14:26:46,601 :                    INFO : EPOCH - 3 : training on 5661152 raw words (2321730 effective words) took 2.5s, 930313 effective words/s
# 2019-12-05 14:26:47,614 :                    INFO : EPOCH 4 - PROGRESS: at 40.45% examples, 932600 words/s, in_qsize 15, out_qsize 0
# 2019-12-05 14:26:48,614 :                    INFO : EPOCH 4 - PROGRESS: at 81.86% examples, 948959 words/s, in_qsize 16, out_qsize 1
# 2019-12-05 14:26:49,029 :                    INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-12-05 14:26:49,036 :                    INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-12-05 14:26:49,038 :                    INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-12-05 14:26:49,041 :                    INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-12-05 14:26:49,041 :                    INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-12-05 14:26:49,042 :                    INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-05 14:26:49,043 :                    INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-05 14:26:49,044 :                    INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-05 14:26:49,045 :                    INFO : EPOCH - 4 : training on 5661152 raw words (2322735 effective words) took 2.4s, 954951 effective words/s
# 2019-12-05 14:26:50,063 :                    INFO : EPOCH 5 - PROGRESS: at 41.52% examples, 955267 words/s, in_qsize 16, out_qsize 0
# 2019-12-05 14:26:51,066 :                    INFO : EPOCH 5 - PROGRESS: at 82.92% examples, 958623 words/s, in_qsize 15, out_qsize 0
# 2019-12-05 14:26:51,453 :                    INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-12-05 14:26:51,458 :                    INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-12-05 14:26:51,459 :                    INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-12-05 14:26:51,462 :                    INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-12-05 14:26:51,463 :                    INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-12-05 14:26:51,464 :                    INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-05 14:26:51,464 :                    INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-05 14:26:51,465 :                    INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-05 14:26:51,466 :                    INFO : EPOCH - 5 : training on 5661152 raw words (2322191 effective words) took 2.4s, 965045 effective words/s
# 2019-12-05 14:26:51,466 :                    INFO : training on a 28305760 raw words (11612240 effective words) took 12.3s, 942616 effective words/s

# %%
model.wv.vectors.shape
# Out:
# (6506, 32)

# %% [markdown]
# ### Classifying averaged vectors with random forest as a baseline

# %% [markdown]
# Calculating average vector for each review:

# %%
def avg_vec(reviews, model, num_features):
    index2word_set = set(model.wv.index2word)
    t_df = pd.DataFrame(reviews).applymap(lambda t:
                                          [(model[x]) if x in index2word_set
                                           else np.full(num_features, np.nan)
                                           for x in t])
    return t_df.iloc[:, 0].apply(lambda x:
                                 np.nanmean(np.array(x),
                                            axis=0)).values.tolist()

# %%
print("Converting train reviews to wordlist...")
clean_train_reviews = series_to_wordlist(train_data['review'],
                                         remove_stopwords=True)
trainDataVecs = avg_vec(clean_train_reviews, model, num_features)
# Out:
# Converting train reviews to wordlist...

# %%
print("Converting test reviews to wordlist...")
clean_test_reviews = series_to_wordlist(test_data['review'],
                                        remove_stopwords=True)
testDataVecs = avg_vec(clean_test_reviews, model, num_features)
# Out:
# Converting test reviews to wordlist...

# %%
X_train_vec, X_test_vec, y_train_vec, y_test_vec = \
    trainDataVecs, testDataVecs,\
    train_data['sentiment'], test_data['sentiment']

# %%
forest_train = RandomForestClassifier(n_estimators=100,
                                      n_jobs=-1, random_state=42)
print("Fitting a random forest to labeled training data...")
forest_train.fit(X_train_vec, y_train_vec)
# Out:
# Fitting a random forest to labeled training data...
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
roc_auc_score(y_test_vec,
              forest_train.predict_proba(X_test_vec)[:, 1])
# Out:
# 0.8985659871999999

# %% [markdown]
# ## Using LSTM

# %%
def get_vec(reviews, model, num_features):
    index2word_set = set(model.wv.index2word)
    t_df = pd.DataFrame(reviews).applymap(lambda t:
                                          [(model[x]) for x in t
                                           if x in index2word_set])

    return t_df

# %%
train_vecs = get_vec(clean_train_reviews, model, num_features)

# %%
test_vecs = get_vec(clean_test_reviews, model, num_features)

# %%
maxlen = 80

# %%
train_vecs = sequence.pad_sequences(train_vecs.iloc[:,0].values,
                                    maxlen=maxlen)

# %%
test_vecs = sequence.pad_sequences(test_vecs.iloc[:,0].values,
                                   maxlen=maxlen)

# %%
lstm_model = Sequential()
lstm_model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
lstm_model.add(Dense(1, activation="sigmoid"))

# %%
lstm_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', 
                                            patience=5,
                                            verbose=1,
                                            factor=0.2)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,
                   patience=10)

# %%
callback_list = [learning_rate_reduction, es]

# %%
history = lstm_model.fit(
    train_vecs.astype('float'),
    y_train_vec.values,
    batch_size=64,
    epochs=50,
    validation_split=0.1,
    callbacks=callback_list
)
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/50
# 22500/22500 [==============================] - 51s 2ms/sample - loss: 0.5202 - accuracy: 0.7465 - val_loss: 0.4594 - val_accuracy: 0.7920
# Epoch 2/50
# 22500/22500 [==============================] - 44s 2ms/sample - loss: 0.4669 - accuracy: 0.7819 - val_loss: 0.4241 - val_accuracy: 0.8012
# Epoch 3/50
# 22500/22500 [==============================] - 44s 2ms/sample - loss: 0.4445 - accuracy: 0.7917 - val_loss: 0.4322 - val_accuracy: 0.7992
# Epoch 4/50
# 22500/22500 [==============================] - 47s 2ms/sample - loss: 0.4330 - accuracy: 0.8026 - val_loss: 0.4051 - val_accuracy: 0.8104
# Epoch 5/50
# 22500/22500 [==============================] - 45s 2ms/sample - loss: 0.4242 - accuracy: 0.8049 - val_loss: 0.3953 - val_accuracy: 0.8180
# Epoch 6/50
# 22500/22500 [==============================] - 46s 2ms/sample - loss: 0.4167 - accuracy: 0.8112 - val_loss: 0.3949 - val_accuracy: 0.8220
# Epoch 7/50
# 22500/22500 [==============================] - 56s 2ms/sample - loss: 0.4048 - accuracy: 0.8147 - val_loss: 0.3934 - val_accuracy: 0.8224
# Epoch 8/50
# 22500/22500 [==============================] - 56s 2ms/sample - loss: 0.3989 - accuracy: 0.8203 - val_loss: 0.3866 - val_accuracy: 0.8276
# Epoch 9/50
# 22500/22500 [==============================] - 56s 3ms/sample - loss: 0.3908 - accuracy: 0.8223 - val_loss: 0.3870 - val_accuracy: 0.8268
# Epoch 10/50
# 22500/22500 [==============================] - 56s 3ms/sample - loss: 0.3896 - accuracy: 0.8199 - val_loss: 0.3915 - val_accuracy: 0.8312
# Epoch 11/50
# 22500/22500 [==============================] - 57s 3ms/sample - loss: 0.3799 - accuracy: 0.8294 - val_loss: 0.3822 - val_accuracy: 0.8356
# Epoch 12/50
# 22500/22500 [==============================] - 57s 3ms/sample - loss: 0.3779 - accuracy: 0.8305 - val_loss: 0.3841 - val_accuracy: 0.8148
# Epoch 13/50
# 22500/22500 [==============================] - 56s 2ms/sample - loss: 0.3705 - accuracy: 0.8337 - val_loss: 0.3783 - val_accuracy: 0.8256
# Epoch 14/50
# 22500/22500 [==============================] - 55s 2ms/sample - loss: 0.3698 - accuracy: 0.8322 - val_loss: 0.3768 - val_accuracy: 0.8292
# Epoch 15/50
# 22500/22500 [==============================] - 56s 2ms/sample - loss: 0.3637 - accuracy: 0.8374 - val_loss: 0.3715 - val_accuracy: 0.8364
# Epoch 16/50
# 22500/22500 [==============================] - 56s 2ms/sample - loss: 0.3558 - accuracy: 0.8422 - val_loss: 0.3816 - val_accuracy: 0.8336
# Epoch 17/50
# 22500/22500 [==============================] - 44s 2ms/sample - loss: 0.3500 - accuracy: 0.8406 - val_loss: 0.3830 - val_accuracy: 0.8276
# Epoch 18/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.3485 - accuracy: 0.8446 - val_loss: 0.3752 - val_accuracy: 0.8336
# Epoch 19/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.3455 - accuracy: 0.8459 - val_loss: 0.3808 - val_accuracy: 0.8340
# Epoch 20/50
# 22464/22500 [============================>.] - ETA: 0s - loss: 0.3441 - accuracy: 0.8454
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.3439 - accuracy: 0.8456 - val_loss: 0.3779 - val_accuracy: 0.8380
# Epoch 21/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.3302 - accuracy: 0.8541 - val_loss: 0.3741 - val_accuracy: 0.8360
# Epoch 22/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.3243 - accuracy: 0.8563 - val_loss: 0.3736 - val_accuracy: 0.8408
# Epoch 23/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.3231 - accuracy: 0.8573 - val_loss: 0.3723 - val_accuracy: 0.8404
# Epoch 24/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.3222 - accuracy: 0.8564 - val_loss: 0.3744 - val_accuracy: 0.8408
# Epoch 25/50
# 22464/22500 [============================>.] - ETA: 0s - loss: 0.3231 - accuracy: 0.8566
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 22500/22500 [==============================] - 34s 2ms/sample - loss: 0.3231 - accuracy: 0.8566 - val_loss: 0.3760 - val_accuracy: 0.8324
# Epoch 00025: early stopping

# %%
plot_history(history)

# %%
roc_auc_score(y_test_vec.values,
              lstm_model.predict(test_vecs.astype('float')).reshape(-1))
# Out:
# 0.9294908

# %%
with open('data/lstm_hist_32f.pkl','wb') as handle:
    pickle.dump(history.history, handle)

# %% [markdown]
# ## Same, but with GRU

# %%
gru_model = Sequential()
gru_model.add(GRU(100, dropout=0.2, recurrent_dropout=0.2))
gru_model.add(Dense(1, activation="sigmoid"))

# %%
gru_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
history = gru_model.fit(
    train_vecs.astype('float'),
    y_train_vec.values,
    batch_size=64,
    epochs=50,
    validation_split=0.1,
    callbacks=callback_list
)
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/50
# 22500/22500 [==============================] - 48s 2ms/sample - loss: 6.9772 - accuracy: 0.6649 - val_loss: 0.6170 - val_accuracy: 0.6576
# Epoch 2/50
# 22500/22500 [==============================] - 46s 2ms/sample - loss: 0.5924 - accuracy: 0.6831 - val_loss: 0.6130 - val_accuracy: 0.6556
# Epoch 3/50
# 22500/22500 [==============================] - 49s 2ms/sample - loss: 0.9121 - accuracy: 0.6800 - val_loss: 0.6142 - val_accuracy: 0.6580
# Epoch 4/50
# 22500/22500 [==============================] - 51s 2ms/sample - loss: 0.6898 - accuracy: 0.6730 - val_loss: 0.6280 - val_accuracy: 0.6480
# Epoch 5/50
# 22500/22500 [==============================] - 52s 2ms/sample - loss: 0.6049 - accuracy: 0.6674 - val_loss: 0.6209 - val_accuracy: 0.6652
# Epoch 6/50
# 22500/22500 [==============================] - 47s 2ms/sample - loss: 0.5958 - accuracy: 0.6760 - val_loss: 0.6175 - val_accuracy: 0.6640
# Epoch 7/50
# 22464/22500 [============================>.] - ETA: 0s - loss: 0.5901 - accuracy: 0.6749
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 22500/22500 [==============================] - 46s 2ms/sample - loss: 0.5900 - accuracy: 0.6750 - val_loss: 0.6139 - val_accuracy: 0.6620
# Epoch 8/50
# 22500/22500 [==============================] - 47s 2ms/sample - loss: 0.5874 - accuracy: 0.6809 - val_loss: 0.6129 - val_accuracy: 0.6632
# Epoch 9/50
# 22500/22500 [==============================] - 50s 2ms/sample - loss: 0.5889 - accuracy: 0.6857 - val_loss: 0.6122 - val_accuracy: 0.6644
# Epoch 10/50
# 22500/22500 [==============================] - 47s 2ms/sample - loss: 0.5842 - accuracy: 0.6906 - val_loss: 0.6108 - val_accuracy: 0.6668
# Epoch 11/50
# 22500/22500 [==============================] - 44s 2ms/sample - loss: 0.5811 - accuracy: 0.6904 - val_loss: 0.6100 - val_accuracy: 0.6664
# Epoch 12/50
# 22500/22500 [==============================] - 40s 2ms/sample - loss: 0.5795 - accuracy: 0.6873 - val_loss: 0.6077 - val_accuracy: 0.6704
# Epoch 13/50
# 22500/22500 [==============================] - 37s 2ms/sample - loss: 0.5780 - accuracy: 0.6883 - val_loss: 0.6066 - val_accuracy: 0.6700
# Epoch 14/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.6609 - accuracy: 0.6828 - val_loss: 0.6119 - val_accuracy: 0.6636
# Epoch 15/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.5827 - accuracy: 0.6882 - val_loss: 0.6075 - val_accuracy: 0.6736
# Epoch 16/50
# 22500/22500 [==============================] - 37s 2ms/sample - loss: 0.5794 - accuracy: 0.6919 - val_loss: 0.6049 - val_accuracy: 0.6768
# Epoch 17/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.5717 - accuracy: 0.6974 - val_loss: 0.6018 - val_accuracy: 0.6756
# Epoch 18/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.9535 - accuracy: 0.6808 - val_loss: 0.6105 - val_accuracy: 0.6704
# Epoch 19/50
# 22500/22500 [==============================] - 38s 2ms/sample - loss: 0.5884 - accuracy: 0.6816 - val_loss: 0.6097 - val_accuracy: 0.6768
# Epoch 20/50
# 22500/22500 [==============================] - 37s 2ms/sample - loss: 0.5845 - accuracy: 0.6864 - val_loss: 0.6091 - val_accuracy: 0.6712
# Epoch 21/50
# 22500/22500 [==============================] - 35s 2ms/sample - loss: 0.5778 - accuracy: 0.6914 - val_loss: 0.6074 - val_accuracy: 0.6684
# Epoch 22/50
# 22464/22500 [============================>.] - ETA: 0s - loss: 0.5849 - accuracy: 0.6891
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 22500/22500 [==============================] - 27s 1ms/sample - loss: 0.5848 - accuracy: 0.6891 - val_loss: 0.6096 - val_accuracy: 0.6692
# Epoch 23/50
# 22500/22500 [==============================] - 26s 1ms/sample - loss: 0.5811 - accuracy: 0.6903 - val_loss: 0.6088 - val_accuracy: 0.6696
# Epoch 24/50
# 22500/22500 [==============================] - 27s 1ms/sample - loss: 0.5795 - accuracy: 0.6867 - val_loss: 0.6080 - val_accuracy: 0.6692
# Epoch 25/50
# 22500/22500 [==============================] - 28s 1ms/sample - loss: 0.5787 - accuracy: 0.6892 - val_loss: 0.6073 - val_accuracy: 0.6696
# Epoch 26/50
# 22500/22500 [==============================] - 27s 1ms/sample - loss: 0.5763 - accuracy: 0.6879 - val_loss: 0.6065 - val_accuracy: 0.6704
# Epoch 27/50
# 22464/22500 [============================>.] - ETA: 0s - loss: 0.5736 - accuracy: 0.6931
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 22500/22500 [==============================] - 27s 1ms/sample - loss: 0.5737 - accuracy: 0.6932 - val_loss: 0.6056 - val_accuracy: 0.6716
# Epoch 00027: early stopping

# %%
plot_history(history)

# %%
roc_auc_score(y_test_vec.values,
              gru_model.predict(test_vecs.astype('float')).reshape(-1))
# Out:
# 0.7585095968
