# %% [markdown]
# # HW 16: NLP+LSTM. 128 features

# %%
import re
import logging
import time

from bs4 import BeautifulSoup
from gensim.models import Word2Vec
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier
from tqdm import tqdm_notebook

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Dense,
    Embedding,
    LSTM,
    GRU,
    SpatialDropout1D
)
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.datasets import imdb
from sklearn.metrics import roc_auc_score
from tensorflow.keras.utils import get_file
import pickle
from tqdm.notebook import tqdm

# %%
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)

# %%
def plot_history(history):
    history_dict = history.history
    loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']
    epochs = range(1, len(loss_values) + 1)


    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

    ax1.plot(epochs, loss_values, 'bo',
             label='Training loss')
    ax1.plot(epochs, val_loss_values, 'b',
             label='Validation loss')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.set_xscale('log')

    acc_values = history_dict['accuracy']
    val_acc_values = history_dict['val_accuracy']

    ax2.plot(epochs, acc_values, 'bo',
             label='Training acc')
    ax2.plot(epochs, val_acc_values, 'b',
             label='Validation acc')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Accuracy')
    ax2.set_xscale('log')


    plt.legend()
    plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %load_ext pycodestyle_magic

# %%
logging.basicConfig(format='%(asctime)s :\
                    %(levelname)s : %(message)s', level=logging.INFO)
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /home/anton/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/anton/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Import data

# %% [markdown]
# Getting the keras imdb dataset and converting it back to actual words

# %%
imdb = tf.keras.datasets.imdb
(train_data, train_labels), (test_data, test_labels) =\
    imdb.load_data(num_words=10000)

word_index = imdb.get_word_index()
reverse_word_index = dict([(value, key) for
                           (key, value) in word_index.items()])

# %%
train_reviews = [' '.join([reverse_word_index.get(i-3, "?")
                           for i in t]) for t in tqdm(train_data)]
# Out:
# HBox(children=(IntProgress(value=0, max=25000), HTML(value='')))

# %%
test_reviews = [' '.join([reverse_word_index.get(i-3, "?")
                          for i in t]) for t in tqdm(test_data)]
# Out:
# HBox(children=(IntProgress(value=0, max=25000), HTML(value='')))

# %%
train_data = pd.DataFrame(np.array(train_reviews),
                          columns=['review'], index=range(len(train_reviews)))
train_data['sentiment'] = train_labels
train_data.head()
# Out:
#                                               review  sentiment
# 0  ? this film was just brilliant casting locatio...          1
# 1  ? big hair big boobs bad music and a giant saf...          0
# 2  ? this has to be one of the worst films of the...          0
# 3  ? the ? ? at storytelling the traditional sort...          1
# 4  ? worst mistake of my life br br i picked this...          0

# %%
test_data = pd.DataFrame(np.array(test_reviews),
                         columns=['review'])
test_data['sentiment'] = test_labels
test_data.head()
# Out:
#                                               review  sentiment
# 0  ? please give this one a miss br br ? ? and th...          0
# 1  ? this film requires a lot of patience because...          1
# 2  ? many animation buffs consider ? ? the great ...          1
# 3  ? i generally love this type of movie however ...          0
# 4  ? like some other people wrote i'm a die hard ...          1

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
wordnet_lemmatizer = WordNetLemmatizer()

# %% [markdown]
# ### Helper functions

# %%
def series_to_wordlist(series, remove_stopwords=False):

    train_text0 = series.apply(lambda text:
                               BeautifulSoup(text, 'html.parser').get_text())
    train_text0 = train_text0.str.replace("[^a-zA-Z]", " ").str.lower()
    train_words = train_text0.str.split()

    if remove_stopwords:
        stops = set(stopwords.words("english"))
        train_words = train_words.apply(lambda text:
                                        [wordnet_lemmatizer.lemmatize(t, 'v')
                                         for t in text if t not in stops])
    else:
        train_words = train_words.apply(lambda text:
                                        [wordnet_lemmatizer.lemmatize(t, 'v')
                                         for t in text])

    return train_words.values.ravel()

# %%
def series_to_sentences(series, remove_stopwords=False):

    train_text = series.apply(lambda text:
                              BeautifulSoup(text, 'html.parser').get_text())
    train_tokenize = train_text.str.strip().apply(tokenizer.tokenize)

    tt_df = pd.DataFrame(train_tokenize.values.tolist())
    tt_df = tt_df.replace("[^a-zA-Z]", " ", regex=True)
    tt_df = tt_df.applymap(lambda x: x.lower() if pd.notnull(x) else '')
    stops = set(stopwords.words("english"))

    if remove_stopwords:
        tt_df = tt_df.applymap(lambda x: [wordnet_lemmatizer.lemmatize(t, 'v')
                                          for t in x.split()
                                          if t not in stops])
    else:
        tt_df = tt_df.applymap(lambda x: [wordnet_lemmatizer.lemmatize(t, 'v')
                                          for t in x.split()])

    idx = [x != [] for x in tt_df.values.ravel()]
    return tt_df.values.ravel()[idx]

# %%
# %%time
print('Parsing sentences from training set')
sentences = series_to_sentences(train_data['review'])
# Out:
# Parsing sentences from training set
# CPU times: user 1min 7s, sys: 923 ms, total: 1min 8s
# Wall time: 1min 8s

# %%
all_sentences = sentences

# %%
print(all_sentences[0])
# Out:
# ['this', 'film', 'be', 'just', 'brilliant', 'cast', 'location', 'scenery', 'story', 'direction', 'everyone', 's', 'really', 'suit', 'the', 'part', 'they', 'play', 'and', 'you', 'could', 'just', 'imagine', 'be', 'there', 'robert']

# %% [markdown]
# ### Defining the Word2Vec parameters

# %%
num_features = 128                  
min_word_count = 40        
num_workers = 8
context = 10                                                                                   
downsampling = 1e-4

# %% [markdown]
# Training the model

# %%
# Initialize and train the model (this will take some time)
print("Training model...")
model = Word2Vec(
    all_sentences,
    workers=8,
    size=num_features,
    min_count=min_word_count,
    window=context,
    sample=downsampling,
    seed=42
)
# Out:
# 2019-12-05 14:35:06,190 :                    INFO : collecting all words and their counts
# 2019-12-05 14:35:06,191 :                    INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-12-05 14:35:06,223 :                    INFO : PROGRESS: at sentence #10000, processed 166536 words, keeping 6492 word types
# 2019-12-05 14:35:06,252 :                    INFO : PROGRESS: at sentence #20000, processed 342739 words, keeping 7289 word types
# 2019-12-05 14:35:06,277 :                    INFO : PROGRESS: at sentence #30000, processed 508010 words, keeping 7545 word types
# 2019-12-05 14:35:06,320 :                    INFO : PROGRESS: at sentence #40000, processed 682510 words, keeping 7632 word types
# 2019-12-05 14:35:06,347 :                    INFO : PROGRESS: at sentence #50000, processed 856794 words, keeping 7666 word types
# Training model...
# 2019-12-05 14:35:06,385 :                    INFO : PROGRESS: at sentence #60000, processed 1030291 words, keeping 7680 word types
# 2019-12-05 14:35:06,426 :                    INFO : PROGRESS: at sentence #70000, processed 1201078 words, keeping 7685 word types
# 2019-12-05 14:35:06,464 :                    INFO : PROGRESS: at sentence #80000, processed 1376792 words, keeping 7686 word types
# 2019-12-05 14:35:06,495 :                    INFO : PROGRESS: at sentence #90000, processed 1550921 words, keeping 7687 word types
# 2019-12-05 14:35:06,532 :                    INFO : PROGRESS: at sentence #100000, processed 1718983 words, keeping 7687 word types
# 2019-12-05 14:35:06,562 :                    INFO : PROGRESS: at sentence #110000, processed 1893836 words, keeping 7687 word types
# 2019-12-05 14:35:06,602 :                    INFO : PROGRESS: at sentence #120000, processed 2069544 words, keeping 7687 word types
# 2019-12-05 14:35:06,642 :                    INFO : PROGRESS: at sentence #130000, processed 2244569 words, keeping 7687 word types
# 2019-12-05 14:35:06,683 :                    INFO : PROGRESS: at sentence #140000, processed 2419031 words, keeping 7687 word types
# 2019-12-05 14:35:06,724 :                    INFO : PROGRESS: at sentence #150000, processed 2593119 words, keeping 7687 word types
# 2019-12-05 14:35:06,765 :                    INFO : PROGRESS: at sentence #160000, processed 2770608 words, keeping 7689 word types
# 2019-12-05 14:35:06,808 :                    INFO : PROGRESS: at sentence #170000, processed 2948298 words, keeping 7689 word types
# 2019-12-05 14:35:06,839 :                    INFO : PROGRESS: at sentence #180000, processed 3119850 words, keeping 7689 word types
# 2019-12-05 14:35:06,870 :                    INFO : PROGRESS: at sentence #190000, processed 3290858 words, keeping 7689 word types
# 2019-12-05 14:35:06,907 :                    INFO : PROGRESS: at sentence #200000, processed 3469573 words, keeping 7689 word types
# 2019-12-05 14:35:06,938 :                    INFO : PROGRESS: at sentence #210000, processed 3646583 words, keeping 7689 word types
# 2019-12-05 14:35:06,971 :                    INFO : PROGRESS: at sentence #220000, processed 3822996 words, keeping 7689 word types
# 2019-12-05 14:35:07,002 :                    INFO : PROGRESS: at sentence #230000, processed 3998987 words, keeping 7689 word types
# 2019-12-05 14:35:07,040 :                    INFO : PROGRESS: at sentence #240000, processed 4170662 words, keeping 7689 word types
# 2019-12-05 14:35:07,067 :                    INFO : PROGRESS: at sentence #250000, processed 4339066 words, keeping 7689 word types
# 2019-12-05 14:35:07,114 :                    INFO : PROGRESS: at sentence #260000, processed 4516163 words, keeping 7689 word types
# 2019-12-05 14:35:07,142 :                    INFO : PROGRESS: at sentence #270000, processed 4688763 words, keeping 7689 word types
# 2019-12-05 14:35:07,180 :                    INFO : PROGRESS: at sentence #280000, processed 4857734 words, keeping 7689 word types
# 2019-12-05 14:35:07,216 :                    INFO : PROGRESS: at sentence #290000, processed 5033020 words, keeping 7689 word types
# 2019-12-05 14:35:07,253 :                    INFO : PROGRESS: at sentence #300000, processed 5211555 words, keeping 7689 word types
# 2019-12-05 14:35:07,294 :                    INFO : PROGRESS: at sentence #310000, processed 5388739 words, keeping 7689 word types
# 2019-12-05 14:35:07,337 :                    INFO : PROGRESS: at sentence #320000, processed 5561026 words, keeping 7689 word types
# 2019-12-05 14:35:07,358 :                    INFO : collected 7689 word types from a corpus of 5661152 raw words and 325662 sentences
# 2019-12-05 14:35:07,359 :                    INFO : Loading a fresh vocabulary
# 2019-12-05 14:35:07,369 :                    INFO : effective_min_count=40 retains 6506 unique words (84% of original 7689, drops 1183)
# 2019-12-05 14:35:07,370 :                    INFO : effective_min_count=40 leaves 5619744 word corpus (99% of original 5661152, drops 41408)
# 2019-12-05 14:35:07,389 :                    INFO : deleting the raw counts dictionary of 7689 items
# 2019-12-05 14:35:07,390 :                    INFO : sample=0.0001 downsamples 448 most-common words
# 2019-12-05 14:35:07,390 :                    INFO : downsampling leaves estimated 2322594 word corpus (41.3% of prior 5619744)
# 2019-12-05 14:35:07,415 :                    INFO : estimated required memory for 6506 words and 128 dimensions: 9915144 bytes
# 2019-12-05 14:35:07,418 :                    INFO : resetting layer weights
# 2019-12-05 14:35:07,503 :                    INFO : training model with 8 workers on 6506 vocabulary and 128 features, using sg=0 hs=0 sample=0.0001 negative=5 window=10
# 2019-12-05 14:35:08,512 :                    INFO : EPOCH 1 - PROGRESS: at 37.58% examples, 868101 words/s, in_qsize 15, out_qsize 0
# 2019-12-05 14:35:09,514 :                    INFO : EPOCH 1 - PROGRESS: at 76.43% examples, 884599 words/s, in_qsize 13, out_qsize 2
# 2019-12-05 14:35:10,070 :                    INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-12-05 14:35:10,078 :                    INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-12-05 14:35:10,081 :                    INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-12-05 14:35:10,082 :                    INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-12-05 14:35:10,083 :                    INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-12-05 14:35:10,084 :                    INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-05 14:35:10,088 :                    INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-05 14:35:10,089 :                    INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-05 14:35:10,089 :                    INFO : EPOCH - 1 : training on 5661152 raw words (2322856 effective words) took 2.6s, 900980 effective words/s
# 2019-12-05 14:35:11,104 :                    INFO : EPOCH 2 - PROGRESS: at 39.37% examples, 905149 words/s, in_qsize 16, out_qsize 1
# 2019-12-05 14:35:12,112 :                    INFO : EPOCH 2 - PROGRESS: at 78.21% examples, 900510 words/s, in_qsize 16, out_qsize 2
# 2019-12-05 14:35:12,630 :                    INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-12-05 14:35:12,641 :                    INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-12-05 14:35:12,643 :                    INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-12-05 14:35:12,647 :                    INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-12-05 14:35:12,649 :                    INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-12-05 14:35:12,650 :                    INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-05 14:35:12,651 :                    INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-05 14:35:12,653 :                    INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-05 14:35:12,654 :                    INFO : EPOCH - 2 : training on 5661152 raw words (2322440 effective words) took 2.6s, 909284 effective words/s
# 2019-12-05 14:35:13,687 :                    INFO : EPOCH 3 - PROGRESS: at 37.58% examples, 849270 words/s, in_qsize 16, out_qsize 0
# 2019-12-05 14:35:14,696 :                    INFO : EPOCH 3 - PROGRESS: at 66.29% examples, 757545 words/s, in_qsize 14, out_qsize 1
# 2019-12-05 14:35:15,647 :                    INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-12-05 14:35:15,650 :                    INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-12-05 14:35:15,656 :                    INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-12-05 14:35:15,663 :                    INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-12-05 14:35:15,664 :                    INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-12-05 14:35:15,665 :                    INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-05 14:35:15,666 :                    INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-05 14:35:15,671 :                    INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-05 14:35:15,672 :                    INFO : EPOCH - 3 : training on 5661152 raw words (2322377 effective words) took 3.0s, 772501 effective words/s
# 2019-12-05 14:35:16,699 :                    INFO : EPOCH 4 - PROGRESS: at 35.46% examples, 804648 words/s, in_qsize 14, out_qsize 1
# 2019-12-05 14:35:17,713 :                    INFO : EPOCH 4 - PROGRESS: at 73.89% examples, 845112 words/s, in_qsize 14, out_qsize 1
# 2019-12-05 14:35:18,450 :                    INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-12-05 14:35:18,456 :                    INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-12-05 14:35:18,466 :                    INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-12-05 14:35:18,469 :                    INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-12-05 14:35:18,470 :                    INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-12-05 14:35:18,472 :                    INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-05 14:35:18,473 :                    INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-05 14:35:18,477 :                    INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-05 14:35:18,477 :                    INFO : EPOCH - 4 : training on 5661152 raw words (2322793 effective words) took 2.8s, 831737 effective words/s
# 2019-12-05 14:35:19,488 :                    INFO : EPOCH 5 - PROGRESS: at 39.72% examples, 916859 words/s, in_qsize 14, out_qsize 1
# 2019-12-05 14:35:20,495 :                    INFO : EPOCH 5 - PROGRESS: at 81.86% examples, 946107 words/s, in_qsize 13, out_qsize 2
# 2019-12-05 14:35:20,883 :                    INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-12-05 14:35:20,888 :                    INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-12-05 14:35:20,893 :                    INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-12-05 14:35:20,895 :                    INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-12-05 14:35:20,896 :                    INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-12-05 14:35:20,897 :                    INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-05 14:35:20,899 :                    INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-05 14:35:20,901 :                    INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-05 14:35:20,902 :                    INFO : EPOCH - 5 : training on 5661152 raw words (2323205 effective words) took 2.4s, 962001 effective words/s
# 2019-12-05 14:35:20,902 :                    INFO : training on a 28305760 raw words (11613671 effective words) took 13.4s, 866776 effective words/s

# %%
model.wv.vectors.shape
# Out:
# (6506, 128)

# %% [markdown]
# ### Classifying averaged vectors with random forest as a baseline

# %% [markdown]
# Calculating average vector for each review:

# %%
def avg_vec(reviews, model, num_features):
    index2word_set = set(model.wv.index2word)
    t_df = pd.DataFrame(reviews).applymap(lambda t:
                                          [(model[x]) if x in index2word_set
                                           else np.full(num_features, np.nan)
                                           for x in t])
    return t_df.iloc[:, 0].apply(lambda x:
                                 np.nanmean(np.array(x),
                                            axis=0)).values.tolist()

# %%
print("Converting train reviews to wordlist...")
clean_train_reviews = series_to_wordlist(train_data['review'],
                                         remove_stopwords=True)
trainDataVecs = avg_vec(clean_train_reviews, model, num_features)
# Out:
# Converting train reviews to wordlist...

# %%
print("Converting test reviews to wordlist...")
clean_test_reviews = series_to_wordlist(test_data['review'],
                                        remove_stopwords=True)
testDataVecs = avg_vec(clean_test_reviews, model, num_features)
# Out:
# Converting test reviews to wordlist...

# %%
X_train_vec, X_test_vec, y_train_vec, y_test_vec = \
    trainDataVecs, testDataVecs,\
    train_data['sentiment'], test_data['sentiment']

# %%
forest_train = RandomForestClassifier(n_estimators=100,
                                      n_jobs=-1, random_state=42)
print("Fitting a random forest to labeled training data...")
forest_train.fit(X_train_vec, y_train_vec)
# Out:
# Fitting a random forest to labeled training data...
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
roc_auc_score(y_test_vec,
              forest_train.predict_proba(X_test_vec)[:, 1])
# Out:
# 0.9054624800000002

# %% [markdown]
# ## Using LSTM

# %%
def get_vec(reviews, model, num_features):
    index2word_set = set(model.wv.index2word)
    t_df = pd.DataFrame(reviews).applymap(lambda t:
                                          [(model[x]) for x in t
                                           if x in index2word_set])

    return t_df

# %%
train_vecs = get_vec(clean_train_reviews, model, num_features)

# %%
test_vecs = get_vec(clean_test_reviews, model, num_features)

# %%
maxlen = 80

# %%
train_vecs = sequence.pad_sequences(train_vecs.iloc[:,0].values,
                                    maxlen=maxlen)

# %%
test_vecs = sequence.pad_sequences(test_vecs.iloc[:,0].values,
                                   maxlen=maxlen)

# %%
lstm_model = Sequential()
lstm_model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
lstm_model.add(Dense(1, activation="sigmoid"))

# %%
lstm_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', 
                                            patience=5,
                                            verbose=1,
                                            factor=0.2)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,
                   patience=10)

# %%
callback_list = [learning_rate_reduction, es]

# %%
history = lstm_model.fit(
    train_vecs.astype('float'),
    y_train_vec.values,
    batch_size=64,
    epochs=50,
    validation_split=0.1,
    callbacks=callback_list
)
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/50
# 22500/22500 [==============================] - 49s 2ms/sample - loss: 0.4914 - accuracy: 0.7626 - val_loss: 0.4678 - val_accuracy: 0.8048
# Epoch 2/50
# 22500/22500 [==============================] - 43s 2ms/sample - loss: 0.4445 - accuracy: 0.7957 - val_loss: 0.4350 - val_accuracy: 0.8040
# Epoch 3/50
# 22500/22500 [==============================] - 44s 2ms/sample - loss: 0.4273 - accuracy: 0.8060 - val_loss: 0.4156 - val_accuracy: 0.8120
# Epoch 4/50
# 22500/22500 [==============================] - 46s 2ms/sample - loss: 0.4075 - accuracy: 0.8144 - val_loss: 0.3992 - val_accuracy: 0.8116
# Epoch 5/50
# 22500/22500 [==============================] - 45s 2ms/sample - loss: 0.3981 - accuracy: 0.8223 - val_loss: 0.3952 - val_accuracy: 0.8236
# Epoch 6/50
# 22500/22500 [==============================] - 50s 2ms/sample - loss: 0.3883 - accuracy: 0.8270 - val_loss: 0.3894 - val_accuracy: 0.8224
# Epoch 7/50
# 22500/22500 [==============================] - 55s 2ms/sample - loss: 0.3781 - accuracy: 0.8285 - val_loss: 0.3873 - val_accuracy: 0.8296
# Epoch 8/50
# 22500/22500 [==============================] - 55s 2ms/sample - loss: 0.3681 - accuracy: 0.8362 - val_loss: 0.3796 - val_accuracy: 0.8292
# Epoch 9/50
# 22500/22500 [==============================] - 56s 2ms/sample - loss: 0.3636 - accuracy: 0.8386 - val_loss: 0.3814 - val_accuracy: 0.8328
# Epoch 10/50
# 22500/22500 [==============================] - 55s 2ms/sample - loss: 0.3534 - accuracy: 0.8438 - val_loss: 0.3755 - val_accuracy: 0.8364
# Epoch 11/50
# 22500/22500 [==============================] - 55s 2ms/sample - loss: 0.3464 - accuracy: 0.8468 - val_loss: 0.3984 - val_accuracy: 0.8240
# Epoch 12/50
# 22500/22500 [==============================] - 56s 2ms/sample - loss: 0.3361 - accuracy: 0.8533 - val_loss: 0.3777 - val_accuracy: 0.8336
# Epoch 13/50
# 22500/22500 [==============================] - 55s 2ms/sample - loss: 0.3288 - accuracy: 0.8561 - val_loss: 0.3778 - val_accuracy: 0.8360
# Epoch 14/50
# 22500/22500 [==============================] - 55s 2ms/sample - loss: 0.3217 - accuracy: 0.8591 - val_loss: 0.3732 - val_accuracy: 0.8388
# Epoch 15/50
# 22500/22500 [==============================] - 55s 2ms/sample - loss: 0.3151 - accuracy: 0.8620 - val_loss: 0.3805 - val_accuracy: 0.8284
# Epoch 16/50
# 22500/22500 [==============================] - 56s 3ms/sample - loss: 0.3028 - accuracy: 0.8662 - val_loss: 0.3845 - val_accuracy: 0.8360
# Epoch 17/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.3016 - accuracy: 0.8695 - val_loss: 0.3842 - val_accuracy: 0.8468
# Epoch 18/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.2947 - accuracy: 0.8737 - val_loss: 0.3798 - val_accuracy: 0.8456
# Epoch 19/50
# 22464/22500 [============================>.] - ETA: 0s - loss: 0.2844 - accuracy: 0.8767
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.2845 - accuracy: 0.8766 - val_loss: 0.3850 - val_accuracy: 0.8472
# Epoch 20/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.2687 - accuracy: 0.8850 - val_loss: 0.3788 - val_accuracy: 0.8456
# Epoch 21/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.2630 - accuracy: 0.8896 - val_loss: 0.3827 - val_accuracy: 0.8448
# Epoch 22/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.2612 - accuracy: 0.8895 - val_loss: 0.3800 - val_accuracy: 0.8436
# Epoch 23/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.2553 - accuracy: 0.8923 - val_loss: 0.3841 - val_accuracy: 0.8460
# Epoch 24/50
# 22464/22500 [============================>.] - ETA: 0s - loss: 0.2542 - accuracy: 0.8921
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.2541 - accuracy: 0.8922 - val_loss: 0.3942 - val_accuracy: 0.8420
# Epoch 00024: early stopping

# %%
plot_history(history)

# %%
roc_auc_score(y_test_vec.values,
              lstm_model.predict(test_vecs.astype('float')).reshape(-1))
# Out:
# 0.9294065792

# %%
with open('data/lstm_hist_128f.pkl','wb') as handle:
    pickle.dump(history.history, handle)

# %% [markdown]
# ## Same, but with GRU

# %%
gru_model = Sequential()
gru_model.add(GRU(100, dropout=0.2, recurrent_dropout=0.2))
gru_model.add(Dense(1, activation="sigmoid"))

# %%
gru_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
history = gru_model.fit(
    train_vecs.astype('float'),
    y_train_vec.values,
    batch_size=64,
    epochs=50,
    validation_split=0.1,
    callbacks=callback_list
)
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/50
# 22500/22500 [==============================] - 44s 2ms/sample - loss: 0.7665 - accuracy: 0.6627 - val_loss: 0.6165 - val_accuracy: 0.6608
# Epoch 2/50
# 22500/22500 [==============================] - 43s 2ms/sample - loss: 0.6284 - accuracy: 0.6632 - val_loss: 0.6320 - val_accuracy: 0.6404
# Epoch 3/50
# 22500/22500 [==============================] - 49s 2ms/sample - loss: 0.6057 - accuracy: 0.6683 - val_loss: 0.6182 - val_accuracy: 0.6636
# Epoch 4/50
# 22500/22500 [==============================] - 49s 2ms/sample - loss: 1.5989 - accuracy: 0.6936 - val_loss: 0.6929 - val_accuracy: 0.5652
# Epoch 5/50
# 22500/22500 [==============================] - 49s 2ms/sample - loss: 0.6289 - accuracy: 0.6642 - val_loss: 0.6226 - val_accuracy: 0.6528
# Epoch 6/50
# 22464/22500 [============================>.] - ETA: 0s - loss: 0.5916 - accuracy: 0.6759
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 22500/22500 [==============================] - 51s 2ms/sample - loss: 0.5916 - accuracy: 0.6759 - val_loss: 0.6188 - val_accuracy: 0.6576
# Epoch 7/50
# 22500/22500 [==============================] - 46s 2ms/sample - loss: 2.3915 - accuracy: 0.6902 - val_loss: 0.6251 - val_accuracy: 0.6524
# Epoch 8/50
# 22500/22500 [==============================] - 46s 2ms/sample - loss: 0.5873 - accuracy: 0.6825 - val_loss: 0.6214 - val_accuracy: 0.6548
# Epoch 9/50
# 22500/22500 [==============================] - 47s 2ms/sample - loss: 0.5843 - accuracy: 0.6830 - val_loss: 0.6193 - val_accuracy: 0.6608
# Epoch 10/50
# 22500/22500 [==============================] - 49s 2ms/sample - loss: 0.5842 - accuracy: 0.6840 - val_loss: 0.6181 - val_accuracy: 0.6564
# Epoch 11/50
# 22464/22500 [============================>.] - ETA: 0s - loss: 0.5849 - accuracy: 0.6839
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 22500/22500 [==============================] - 46s 2ms/sample - loss: 0.5849 - accuracy: 0.6840 - val_loss: 0.6171 - val_accuracy: 0.6568
# Epoch 00011: early stopping

# %%
plot_history(history)

# %%
roc_auc_score(y_test_vec.values,
              gru_model.predict(test_vecs.astype('float')).reshape(-1))
# Out:
# 0.7382607840000001
