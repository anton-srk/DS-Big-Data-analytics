# %% [markdown]
# # HW16: NLP+LSTM. 16 features

# %%
import re
import logging
import time

from bs4 import BeautifulSoup
from gensim.models import Word2Vec
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier
from tqdm import tqdm_notebook

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Dense,
    Embedding,
    LSTM,
    GRU,
    SpatialDropout1D
)
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.datasets import imdb
from sklearn.metrics import roc_auc_score
from tensorflow.keras.utils import get_file
import pickle
from tqdm.notebook import tqdm

# %%
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)

# %%
def plot_history(history):
    history_dict = history.history
    loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']
    epochs = range(1, len(loss_values) + 1)


    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

    ax1.plot(epochs, loss_values, 'bo',
             label='Training loss')
    ax1.plot(epochs, val_loss_values, 'b',
             label='Validation loss')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.set_xscale('log')

    acc_values = history_dict['accuracy']
    val_acc_values = history_dict['val_accuracy']

    ax2.plot(epochs, acc_values, 'bo',
             label='Training acc')
    ax2.plot(epochs, val_acc_values, 'b',
             label='Validation acc')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Accuracy')
    ax2.set_xscale('log')


    plt.legend()
    plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %load_ext pycodestyle_magic

# %%
logging.basicConfig(format='%(asctime)s :\
                    %(levelname)s : %(message)s', level=logging.INFO)
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /home/anton/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/anton/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Import data

# %% [markdown]
# Getting the keras imdb dataset and converting it back to actual words

# %%
imdb = tf.keras.datasets.imdb
(train_data, train_labels), (test_data, test_labels) =\
    imdb.load_data(num_words=10000)

word_index = imdb.get_word_index()
reverse_word_index = dict([(value, key) for
                           (key, value) in word_index.items()])

# %%
train_reviews = [' '.join([reverse_word_index.get(i-3, "?")
                           for i in t]) for t in tqdm(train_data)]
# Out:
# HBox(children=(IntProgress(value=0, max=25000), HTML(value='')))

# %%
test_reviews = [' '.join([reverse_word_index.get(i-3, "?")
                          for i in t]) for t in tqdm(test_data)]
# Out:
# HBox(children=(IntProgress(value=0, max=25000), HTML(value='')))

# %%
train_data = pd.DataFrame(np.array(train_reviews),
                          columns=['review'], index=range(len(train_reviews)))
train_data['sentiment'] = train_labels
train_data.head()
# Out:
#                                               review  sentiment
# 0  ? this film was just brilliant casting locatio...          1
# 1  ? big hair big boobs bad music and a giant saf...          0
# 2  ? this has to be one of the worst films of the...          0
# 3  ? the ? ? at storytelling the traditional sort...          1
# 4  ? worst mistake of my life br br i picked this...          0

# %%
test_data = pd.DataFrame(np.array(test_reviews),
                         columns=['review'])
test_data['sentiment'] = test_labels
test_data.head()
# Out:
#                                               review  sentiment
# 0  ? please give this one a miss br br ? ? and th...          0
# 1  ? this film requires a lot of patience because...          1
# 2  ? many animation buffs consider ? ? the great ...          1
# 3  ? i generally love this type of movie however ...          0
# 4  ? like some other people wrote i'm a die hard ...          1

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
wordnet_lemmatizer = WordNetLemmatizer()

# %% [markdown]
# ### Helper functions

# %%
def series_to_wordlist(series, remove_stopwords=False):

    train_text0 = series.apply(lambda text:
                               BeautifulSoup(text, 'html.parser').get_text())
    train_text0 = train_text0.str.replace("[^a-zA-Z]", " ").str.lower()
    train_words = train_text0.str.split()

    if remove_stopwords:
        stops = set(stopwords.words("english"))
        train_words = train_words.apply(lambda text:
                                        [wordnet_lemmatizer.lemmatize(t, 'v')
                                         for t in text if t not in stops])
    else:
        train_words = train_words.apply(lambda text:
                                        [wordnet_lemmatizer.lemmatize(t, 'v')
                                         for t in text])

    return train_words.values.ravel()

# %%
def series_to_sentences(series, remove_stopwords=False):

    train_text = series.apply(lambda text:
                              BeautifulSoup(text, 'html.parser').get_text())
    train_tokenize = train_text.str.strip().apply(tokenizer.tokenize)

    tt_df = pd.DataFrame(train_tokenize.values.tolist())
    tt_df = tt_df.replace("[^a-zA-Z]", " ", regex=True)
    tt_df = tt_df.applymap(lambda x: x.lower() if pd.notnull(x) else '')
    stops = set(stopwords.words("english"))

    if remove_stopwords:
        tt_df = tt_df.applymap(lambda x: [wordnet_lemmatizer.lemmatize(t, 'v')
                                          for t in x.split()
                                          if t not in stops])
    else:
        tt_df = tt_df.applymap(lambda x: [wordnet_lemmatizer.lemmatize(t, 'v')
                                          for t in x.split()])

    idx = [x != [] for x in tt_df.values.ravel()]
    return tt_df.values.ravel()[idx]

# %%
# %%time
print('Parsing sentences from training set')
sentences = series_to_sentences(train_data['review'])
# Out:
# Parsing sentences from training set
# CPU times: user 1min 13s, sys: 1.03 s, total: 1min 14s
# Wall time: 1min 14s

# %%
all_sentences = sentences

# %%
print(all_sentences[0])
# Out:
# ['this', 'film', 'be', 'just', 'brilliant', 'cast', 'location', 'scenery', 'story', 'direction', 'everyone', 's', 'really', 'suit', 'the', 'part', 'they', 'play', 'and', 'you', 'could', 'just', 'imagine', 'be', 'there', 'robert']

# %% [markdown]
# ### Defining the Word2Vec parameters

# %%
num_features = 16                  
min_word_count = 40        
num_workers = 8
context = 10                                                                                   
downsampling = 1e-4

# %% [markdown]
# Training the model

# %%
# Initialize and train the model (this will take some time)
print("Training model...")
model = Word2Vec(
    all_sentences,
    workers=8,
    size=num_features,
    min_count=min_word_count,
    window=context,
    sample=downsampling,
    seed=42
)
# Out:
# 2019-12-05 14:44:27,981 :                    INFO : collecting all words and their counts
# 2019-12-05 14:44:27,982 :                    INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-12-05 14:44:28,035 :                    INFO : PROGRESS: at sentence #10000, processed 166536 words, keeping 6492 word types
# 2019-12-05 14:44:28,096 :                    INFO : PROGRESS: at sentence #20000, processed 342739 words, keeping 7289 word types
# Training model...
# 2019-12-05 14:44:28,150 :                    INFO : PROGRESS: at sentence #30000, processed 508010 words, keeping 7545 word types
# 2019-12-05 14:44:28,205 :                    INFO : PROGRESS: at sentence #40000, processed 682510 words, keeping 7632 word types
# 2019-12-05 14:44:28,275 :                    INFO : PROGRESS: at sentence #50000, processed 856794 words, keeping 7666 word types
# 2019-12-05 14:44:28,326 :                    INFO : PROGRESS: at sentence #60000, processed 1030291 words, keeping 7680 word types
# 2019-12-05 14:44:28,381 :                    INFO : PROGRESS: at sentence #70000, processed 1201078 words, keeping 7685 word types
# 2019-12-05 14:44:28,449 :                    INFO : PROGRESS: at sentence #80000, processed 1376792 words, keeping 7686 word types
# 2019-12-05 14:44:28,513 :                    INFO : PROGRESS: at sentence #90000, processed 1550921 words, keeping 7687 word types
# 2019-12-05 14:44:28,598 :                    INFO : PROGRESS: at sentence #100000, processed 1718983 words, keeping 7687 word types
# 2019-12-05 14:44:28,679 :                    INFO : PROGRESS: at sentence #110000, processed 1893836 words, keeping 7687 word types
# 2019-12-05 14:44:28,743 :                    INFO : PROGRESS: at sentence #120000, processed 2069544 words, keeping 7687 word types
# 2019-12-05 14:44:28,899 :                    INFO : PROGRESS: at sentence #130000, processed 2244569 words, keeping 7687 word types
# 2019-12-05 14:44:29,143 :                    INFO : PROGRESS: at sentence #140000, processed 2419031 words, keeping 7687 word types
# 2019-12-05 14:44:29,392 :                    INFO : PROGRESS: at sentence #150000, processed 2593119 words, keeping 7687 word types
# 2019-12-05 14:44:29,640 :                    INFO : PROGRESS: at sentence #160000, processed 2770608 words, keeping 7689 word types
# 2019-12-05 14:44:29,854 :                    INFO : PROGRESS: at sentence #170000, processed 2948298 words, keeping 7689 word types
# 2019-12-05 14:44:29,930 :                    INFO : PROGRESS: at sentence #180000, processed 3119850 words, keeping 7689 word types
# 2019-12-05 14:44:29,993 :                    INFO : PROGRESS: at sentence #190000, processed 3290858 words, keeping 7689 word types
# 2019-12-05 14:44:30,063 :                    INFO : PROGRESS: at sentence #200000, processed 3469573 words, keeping 7689 word types
# 2019-12-05 14:44:30,121 :                    INFO : PROGRESS: at sentence #210000, processed 3646583 words, keeping 7689 word types
# 2019-12-05 14:44:30,190 :                    INFO : PROGRESS: at sentence #220000, processed 3822996 words, keeping 7689 word types
# 2019-12-05 14:44:30,269 :                    INFO : PROGRESS: at sentence #230000, processed 3998987 words, keeping 7689 word types
# 2019-12-05 14:44:30,337 :                    INFO : PROGRESS: at sentence #240000, processed 4170662 words, keeping 7689 word types
# 2019-12-05 14:44:30,391 :                    INFO : PROGRESS: at sentence #250000, processed 4339066 words, keeping 7689 word types
# 2019-12-05 14:44:30,469 :                    INFO : PROGRESS: at sentence #260000, processed 4516163 words, keeping 7689 word types
# 2019-12-05 14:44:30,549 :                    INFO : PROGRESS: at sentence #270000, processed 4688763 words, keeping 7689 word types
# 2019-12-05 14:44:30,620 :                    INFO : PROGRESS: at sentence #280000, processed 4857734 words, keeping 7689 word types
# 2019-12-05 14:44:30,688 :                    INFO : PROGRESS: at sentence #290000, processed 5033020 words, keeping 7689 word types
# 2019-12-05 14:44:30,754 :                    INFO : PROGRESS: at sentence #300000, processed 5211555 words, keeping 7689 word types
# 2019-12-05 14:44:30,817 :                    INFO : PROGRESS: at sentence #310000, processed 5388739 words, keeping 7689 word types
# 2019-12-05 14:44:30,884 :                    INFO : PROGRESS: at sentence #320000, processed 5561026 words, keeping 7689 word types
# 2019-12-05 14:44:30,925 :                    INFO : collected 7689 word types from a corpus of 5661152 raw words and 325662 sentences
# 2019-12-05 14:44:30,926 :                    INFO : Loading a fresh vocabulary
# 2019-12-05 14:44:30,942 :                    INFO : effective_min_count=40 retains 6506 unique words (84% of original 7689, drops 1183)
# 2019-12-05 14:44:30,944 :                    INFO : effective_min_count=40 leaves 5619744 word corpus (99% of original 5661152, drops 41408)
# 2019-12-05 14:44:30,984 :                    INFO : deleting the raw counts dictionary of 7689 items
# 2019-12-05 14:44:30,985 :                    INFO : sample=0.0001 downsamples 448 most-common words
# 2019-12-05 14:44:30,986 :                    INFO : downsampling leaves estimated 2322594 word corpus (41.3% of prior 5619744)
# 2019-12-05 14:44:31,023 :                    INFO : estimated required memory for 6506 words and 16 dimensions: 4085768 bytes
# 2019-12-05 14:44:31,025 :                    INFO : resetting layer weights
# 2019-12-05 14:44:31,129 :                    INFO : training model with 8 workers on 6506 vocabulary and 16 features, using sg=0 hs=0 sample=0.0001 negative=5 window=10
# 2019-12-05 14:44:32,206 :                    INFO : EPOCH 1 - PROGRESS: at 16.30% examples, 356373 words/s, in_qsize 15, out_qsize 0
# 2019-12-05 14:44:33,211 :                    INFO : EPOCH 1 - PROGRESS: at 23.01% examples, 257884 words/s, in_qsize 15, out_qsize 0
# 2019-12-05 14:44:34,216 :                    INFO : EPOCH 1 - PROGRESS: at 34.51% examples, 260014 words/s, in_qsize 14, out_qsize 1
# 2019-12-05 14:44:35,222 :                    INFO : EPOCH 1 - PROGRESS: at 54.77% examples, 312067 words/s, in_qsize 14, out_qsize 1
# 2019-12-05 14:44:36,228 :                    INFO : EPOCH 1 - PROGRESS: at 75.90% examples, 346985 words/s, in_qsize 13, out_qsize 2
# 2019-12-05 14:44:37,185 :                    INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-12-05 14:44:37,189 :                    INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-12-05 14:44:37,191 :                    INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-12-05 14:44:37,191 :                    INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-12-05 14:44:37,193 :                    INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-12-05 14:44:37,194 :                    INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-05 14:44:37,194 :                    INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-05 14:44:37,196 :                    INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-05 14:44:37,197 :                    INFO : EPOCH - 1 : training on 5661152 raw words (2323693 effective words) took 6.0s, 384601 effective words/s
# 2019-12-05 14:44:38,228 :                    INFO : EPOCH 2 - PROGRESS: at 31.24% examples, 704003 words/s, in_qsize 15, out_qsize 2
# 2019-12-05 14:44:39,237 :                    INFO : EPOCH 2 - PROGRESS: at 57.69% examples, 657879 words/s, in_qsize 13, out_qsize 2
# 2019-12-05 14:44:40,249 :                    INFO : EPOCH 2 - PROGRESS: at 84.57% examples, 644737 words/s, in_qsize 16, out_qsize 1
# 2019-12-05 14:44:40,873 :                    INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-12-05 14:44:40,882 :                    INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-12-05 14:44:40,887 :                    INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-12-05 14:44:40,897 :                    INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-12-05 14:44:40,900 :                    INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-12-05 14:44:40,902 :                    INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-05 14:44:40,917 :                    INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-05 14:44:40,918 :                    INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-05 14:44:40,919 :                    INFO : EPOCH - 2 : training on 5661152 raw words (2323215 effective words) took 3.7s, 625972 effective words/s
# 2019-12-05 14:44:41,950 :                    INFO : EPOCH 3 - PROGRESS: at 28.63% examples, 651866 words/s, in_qsize 15, out_qsize 0
# 2019-12-05 14:44:42,969 :                    INFO : EPOCH 3 - PROGRESS: at 65.44% examples, 753222 words/s, in_qsize 15, out_qsize 0
# 2019-12-05 14:44:43,807 :                    INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-12-05 14:44:43,814 :                    INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-12-05 14:44:43,817 :                    INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-12-05 14:44:43,818 :                    INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-12-05 14:44:43,827 :                    INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-12-05 14:44:43,828 :                    INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-05 14:44:43,829 :                    INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-05 14:44:43,831 :                    INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-05 14:44:43,832 :                    INFO : EPOCH - 3 : training on 5661152 raw words (2321860 effective words) took 2.9s, 802037 effective words/s
# 2019-12-05 14:44:44,875 :                    INFO : EPOCH 4 - PROGRESS: at 30.31% examples, 682282 words/s, in_qsize 15, out_qsize 0
# 2019-12-05 14:44:45,884 :                    INFO : EPOCH 4 - PROGRESS: at 50.41% examples, 574227 words/s, in_qsize 14, out_qsize 1
# 2019-12-05 14:44:46,902 :                    INFO : EPOCH 4 - PROGRESS: at 69.43% examples, 528665 words/s, in_qsize 14, out_qsize 1
# 2019-12-05 14:44:47,918 :                    INFO : EPOCH 4 - PROGRESS: at 90.54% examples, 516468 words/s, in_qsize 16, out_qsize 1
# 2019-12-05 14:44:48,303 :                    INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-12-05 14:44:48,313 :                    INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-12-05 14:44:48,314 :                    INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-12-05 14:44:48,317 :                    INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-12-05 14:44:48,319 :                    INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-12-05 14:44:48,324 :                    INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-05 14:44:48,331 :                    INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-05 14:44:48,336 :                    INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-05 14:44:48,337 :                    INFO : EPOCH - 4 : training on 5661152 raw words (2321670 effective words) took 4.5s, 517809 effective words/s
# 2019-12-05 14:44:49,360 :                    INFO : EPOCH 5 - PROGRESS: at 21.44% examples, 492273 words/s, in_qsize 15, out_qsize 0
# 2019-12-05 14:44:50,361 :                    INFO : EPOCH 5 - PROGRESS: at 42.23% examples, 486867 words/s, in_qsize 16, out_qsize 0
# 2019-12-05 14:44:51,365 :                    INFO : EPOCH 5 - PROGRESS: at 62.50% examples, 481872 words/s, in_qsize 13, out_qsize 2
# 2019-12-05 14:44:52,367 :                    INFO : EPOCH 5 - PROGRESS: at 82.58% examples, 477928 words/s, in_qsize 16, out_qsize 1
# 2019-12-05 14:44:53,155 :                    INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-12-05 14:44:53,164 :                    INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-12-05 14:44:53,170 :                    INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-12-05 14:44:53,171 :                    INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-12-05 14:44:53,173 :                    INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-12-05 14:44:53,175 :                    INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-05 14:44:53,178 :                    INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-05 14:44:53,183 :                    INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-05 14:44:53,184 :                    INFO : EPOCH - 5 : training on 5661152 raw words (2323070 effective words) took 4.8s, 481426 effective words/s
# 2019-12-05 14:44:53,186 :                    INFO : training on a 28305760 raw words (11613508 effective words) took 22.1s, 526547 effective words/s

# %%
model.wv.vectors.shape
# Out:
# (6506, 16)

# %% [markdown]
# ### Classifying averaged vectors with random forest as a baseline

# %% [markdown]
# Calculating average vector for each review:

# %%
def avg_vec(reviews, model, num_features):
    index2word_set = set(model.wv.index2word)
    t_df = pd.DataFrame(reviews).applymap(lambda t:
                                          [(model[x]) if x in index2word_set
                                           else np.full(num_features, np.nan)
                                           for x in t])
    return t_df.iloc[:, 0].apply(lambda x:
                                 np.nanmean(np.array(x),
                                            axis=0)).values.tolist()

# %%
print("Converting train reviews to wordlist...")
clean_train_reviews = series_to_wordlist(train_data['review'],
                                         remove_stopwords=True)
trainDataVecs = avg_vec(clean_train_reviews, model, num_features)
# Out:
# Converting train reviews to wordlist...

# %%
print("Converting test reviews to wordlist...")
clean_test_reviews = series_to_wordlist(test_data['review'],
                                        remove_stopwords=True)
testDataVecs = avg_vec(clean_test_reviews, model, num_features)
# Out:
# Converting test reviews to wordlist...

# %%
X_train_vec, X_test_vec, y_train_vec, y_test_vec = \
    trainDataVecs, testDataVecs,\
    train_data['sentiment'], test_data['sentiment']

# %%
forest_train = RandomForestClassifier(n_estimators=100,
                                      n_jobs=-1, random_state=42)
print("Fitting a random forest to labeled training data...")
forest_train.fit(X_train_vec, y_train_vec)
# Out:
# Fitting a random forest to labeled training data...
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
roc_auc_score(y_test_vec,
              forest_train.predict_proba(X_test_vec)[:, 1])
# Out:
# 0.8828789631999999

# %% [markdown]
# ## Using LSTM

# %%
def get_vec(reviews, model, num_features):
    index2word_set = set(model.wv.index2word)
    t_df = pd.DataFrame(reviews).applymap(lambda t:
                                          [(model[x]) for x in t
                                           if x in index2word_set])

    return t_df

# %%
train_vecs = get_vec(clean_train_reviews, model, num_features)

# %%
test_vecs = get_vec(clean_test_reviews, model, num_features)

# %%
maxlen = 80

# %%
train_vecs = sequence.pad_sequences(train_vecs.iloc[:,0].values,
                                    maxlen=maxlen)

# %%
test_vecs = sequence.pad_sequences(test_vecs.iloc[:,0].values,
                                   maxlen=maxlen)

# %%
lstm_model = Sequential()
lstm_model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
lstm_model.add(Dense(1, activation="sigmoid"))

# %%
lstm_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', 
                                            patience=5,
                                            verbose=1,
                                            factor=0.2)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,
                   patience=10)

# %%
callback_list = [learning_rate_reduction, es]

# %%
history = lstm_model.fit(
    train_vecs.astype('float'),
    y_train_vec.values,
    batch_size=64,
    epochs=50,
    validation_split=0.1,
    callbacks=callback_list
)
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/50
# 22500/22500 [==============================] - 62s 3ms/sample - loss: 0.5346 - accuracy: 0.7337 - val_loss: 0.4517 - val_accuracy: 0.7904
# Epoch 2/50
# 22500/22500 [==============================] - 57s 3ms/sample - loss: 0.4879 - accuracy: 0.7708 - val_loss: 0.4313 - val_accuracy: 0.8044
# Epoch 3/50
# 22500/22500 [==============================] - 56s 3ms/sample - loss: 0.4763 - accuracy: 0.7748 - val_loss: 0.4296 - val_accuracy: 0.8052
# Epoch 4/50
# 22500/22500 [==============================] - 57s 3ms/sample - loss: 0.4618 - accuracy: 0.7809 - val_loss: 0.4137 - val_accuracy: 0.8112
# Epoch 5/50
# 22500/22500 [==============================] - 57s 3ms/sample - loss: 0.4572 - accuracy: 0.7844 - val_loss: 0.4176 - val_accuracy: 0.8084
# Epoch 6/50
# 22500/22500 [==============================] - 57s 3ms/sample - loss: 0.4474 - accuracy: 0.7900 - val_loss: 0.4073 - val_accuracy: 0.8156
# Epoch 7/50
# 22500/22500 [==============================] - 56s 2ms/sample - loss: 0.4398 - accuracy: 0.7948 - val_loss: 0.4069 - val_accuracy: 0.8204
# Epoch 8/50
# 22500/22500 [==============================] - 56s 3ms/sample - loss: 0.4396 - accuracy: 0.7979 - val_loss: 0.3975 - val_accuracy: 0.8248
# Epoch 9/50
# 22500/22500 [==============================] - 57s 3ms/sample - loss: 0.4334 - accuracy: 0.7968 - val_loss: 0.3942 - val_accuracy: 0.8236
# Epoch 10/50
# 22500/22500 [==============================] - 57s 3ms/sample - loss: 0.4240 - accuracy: 0.8023 - val_loss: 0.3863 - val_accuracy: 0.8308
# Epoch 11/50
# 22500/22500 [==============================] - 42s 2ms/sample - loss: 0.4230 - accuracy: 0.8027 - val_loss: 0.3847 - val_accuracy: 0.8256
# Epoch 12/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.4189 - accuracy: 0.8052 - val_loss: 0.3851 - val_accuracy: 0.8248
# Epoch 13/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.4125 - accuracy: 0.8109 - val_loss: 0.3848 - val_accuracy: 0.8244
# Epoch 14/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.4096 - accuracy: 0.8125 - val_loss: 0.3851 - val_accuracy: 0.8288
# Epoch 15/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.4083 - accuracy: 0.8135 - val_loss: 0.3815 - val_accuracy: 0.8312
# Epoch 16/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.4031 - accuracy: 0.8148 - val_loss: 0.3839 - val_accuracy: 0.8280
# Epoch 17/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.4026 - accuracy: 0.8146 - val_loss: 0.3782 - val_accuracy: 0.8356
# Epoch 18/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.4007 - accuracy: 0.8177 - val_loss: 0.3846 - val_accuracy: 0.8272
# Epoch 19/50
# 22500/22500 [==============================] - 33s 1ms/sample - loss: 0.3977 - accuracy: 0.8163 - val_loss: 0.3812 - val_accuracy: 0.8260
# Epoch 20/50
# 22500/22500 [==============================] - 32s 1ms/sample - loss: 0.3923 - accuracy: 0.8192 - val_loss: 0.3825 - val_accuracy: 0.8316
# Epoch 21/50
# 22500/22500 [==============================] - 34s 2ms/sample - loss: 0.3910 - accuracy: 0.8225 - val_loss: 0.3892 - val_accuracy: 0.8288
# Epoch 22/50
# 22464/22500 [============================>.] - ETA: 0s - loss: 0.3838 - accuracy: 0.8251
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.3837 - accuracy: 0.8250 - val_loss: 0.3795 - val_accuracy: 0.8292
# Epoch 23/50
# 22500/22500 [==============================] - 41s 2ms/sample - loss: 0.3774 - accuracy: 0.8294 - val_loss: 0.3774 - val_accuracy: 0.8292
# Epoch 24/50
# 22500/22500 [==============================] - 40s 2ms/sample - loss: 0.3774 - accuracy: 0.8251 - val_loss: 0.3720 - val_accuracy: 0.8308
# Epoch 25/50
# 22500/22500 [==============================] - 42s 2ms/sample - loss: 0.3738 - accuracy: 0.8290 - val_loss: 0.3725 - val_accuracy: 0.8340
# Epoch 26/50
# 22500/22500 [==============================] - 42s 2ms/sample - loss: 0.3738 - accuracy: 0.8305 - val_loss: 0.3735 - val_accuracy: 0.8344
# Epoch 27/50
# 22500/22500 [==============================] - 43s 2ms/sample - loss: 0.3703 - accuracy: 0.8310 - val_loss: 0.3730 - val_accuracy: 0.8320
# Epoch 28/50
# 22500/22500 [==============================] - 38s 2ms/sample - loss: 0.3691 - accuracy: 0.8327 - val_loss: 0.3732 - val_accuracy: 0.8316
# Epoch 29/50
# 22464/22500 [============================>.] - ETA: 0s - loss: 0.3706 - accuracy: 0.8312
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 22500/22500 [==============================] - 39s 2ms/sample - loss: 0.3705 - accuracy: 0.8312 - val_loss: 0.3749 - val_accuracy: 0.8316
# Epoch 30/50
# 22500/22500 [==============================] - 39s 2ms/sample - loss: 0.3633 - accuracy: 0.8356 - val_loss: 0.3720 - val_accuracy: 0.8336
# Epoch 31/50
# 22500/22500 [==============================] - 41s 2ms/sample - loss: 0.3683 - accuracy: 0.8324 - val_loss: 0.3717 - val_accuracy: 0.8344
# Epoch 32/50
# 22500/22500 [==============================] - 40s 2ms/sample - loss: 0.3658 - accuracy: 0.8339 - val_loss: 0.3717 - val_accuracy: 0.8336
# Epoch 33/50
# 22500/22500 [==============================] - 36s 2ms/sample - loss: 0.3636 - accuracy: 0.8355 - val_loss: 0.3717 - val_accuracy: 0.8356
# Epoch 34/50
# 22500/22500 [==============================] - 37s 2ms/sample - loss: 0.3676 - accuracy: 0.8342 - val_loss: 0.3719 - val_accuracy: 0.8344
# Epoch 35/50
# 22500/22500 [==============================] - 31s 1ms/sample - loss: 0.3654 - accuracy: 0.8348 - val_loss: 0.3716 - val_accuracy: 0.8348
# Epoch 36/50
# 22464/22500 [============================>.] - ETA: 0s - loss: 0.3651 - accuracy: 0.8344
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 22500/22500 [==============================] - 30s 1ms/sample - loss: 0.3650 - accuracy: 0.8345 - val_loss: 0.3719 - val_accuracy: 0.8336
# Epoch 37/50
# 22500/22500 [==============================] - 29s 1ms/sample - loss: 0.3629 - accuracy: 0.8360 - val_loss: 0.3718 - val_accuracy: 0.8340
# Epoch 38/50
# 22500/22500 [==============================] - 29s 1ms/sample - loss: 0.3622 - accuracy: 0.8383 - val_loss: 0.3717 - val_accuracy: 0.8348
# Epoch 39/50
# 22500/22500 [==============================] - 29s 1ms/sample - loss: 0.3627 - accuracy: 0.8364 - val_loss: 0.3719 - val_accuracy: 0.8356
# Epoch 40/50
# 22500/22500 [==============================] - 30s 1ms/sample - loss: 0.3626 - accuracy: 0.8369 - val_loss: 0.3717 - val_accuracy: 0.8352
# Epoch 41/50
# 22464/22500 [============================>.] - ETA: 0s - loss: 0.3629 - accuracy: 0.8348
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 22500/22500 [==============================] - 29s 1ms/sample - loss: 0.3629 - accuracy: 0.8349 - val_loss: 0.3718 - val_accuracy: 0.8356
# Epoch 42/50
# 22500/22500 [==============================] - 29s 1ms/sample - loss: 0.3638 - accuracy: 0.8364 - val_loss: 0.3718 - val_accuracy: 0.8356
# Epoch 43/50
# 22500/22500 [==============================] - 30s 1ms/sample - loss: 0.3655 - accuracy: 0.8344 - val_loss: 0.3718 - val_accuracy: 0.8356
# Epoch 44/50
# 22500/22500 [==============================] - 31s 1ms/sample - loss: 0.3638 - accuracy: 0.8336 - val_loss: 0.3718 - val_accuracy: 0.8352
# Epoch 45/50
# 22500/22500 [==============================] - 29s 1ms/sample - loss: 0.3645 - accuracy: 0.8365 - val_loss: 0.3718 - val_accuracy: 0.8344
# Epoch 00045: early stopping

# %%
plot_history(history)

# %%
roc_auc_score(y_test_vec.values,
              lstm_model.predict(test_vecs.astype('float')).reshape(-1))
# Out:
# 0.9253190943999999

# %%
with open('data/lstm_hist_16f.pkl','wb') as handle:
    pickle.dump(history.history, handle)

# %% [markdown]
# ## Same, but with GRU

# %%
gru_model = Sequential()
gru_model.add(GRU(100, dropout=0.2, recurrent_dropout=0.2))
gru_model.add(Dense(1, activation="sigmoid"))

# %%
gru_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
history = gru_model.fit(
    train_vecs.astype('float'),
    y_train_vec.values,
    batch_size=64,
    epochs=50,
    validation_split=0.1,
    callbacks=callback_list
)
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/50
# 22500/22500 [==============================] - 27s 1ms/sample - loss: 0.9362 - accuracy: 0.6552 - val_loss: 0.6358 - val_accuracy: 0.6476
# Epoch 2/50
# 22500/22500 [==============================] - 27s 1ms/sample - loss: 0.6362 - accuracy: 0.6422 - val_loss: 0.6271 - val_accuracy: 0.6468
# Epoch 3/50
# 22500/22500 [==============================] - 27s 1ms/sample - loss: 0.6178 - accuracy: 0.6580 - val_loss: 0.6209 - val_accuracy: 0.6560
# Epoch 4/50
# 22500/22500 [==============================] - 29s 1ms/sample - loss: 10.4620 - accuracy: 0.6588 - val_loss: 0.6392 - val_accuracy: 0.6512
# Epoch 5/50
# 22500/22500 [==============================] - 28s 1ms/sample - loss: 1.1005 - accuracy: 0.6291 - val_loss: 0.6371 - val_accuracy: 0.6420
# Epoch 6/50
# 22500/22500 [==============================] - 26s 1ms/sample - loss: 0.6335 - accuracy: 0.6336 - val_loss: 0.6332 - val_accuracy: 0.6412
# Epoch 7/50
# 22500/22500 [==============================] - 28s 1ms/sample - loss: 0.7493 - accuracy: 0.6204 - val_loss: 0.6394 - val_accuracy: 0.6344
# Epoch 8/50
# 22464/22500 [============================>.] - ETA: 0s - loss: 0.6388 - accuracy: 0.6262
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 22500/22500 [==============================] - 31s 1ms/sample - loss: 0.6387 - accuracy: 0.6264 - val_loss: 0.6360 - val_accuracy: 0.6388
# Epoch 9/50
# 22500/22500 [==============================] - 33s 1ms/sample - loss: 0.7641 - accuracy: 0.6316 - val_loss: 0.6352 - val_accuracy: 0.6372
# Epoch 10/50
# 22500/22500 [==============================] - 27s 1ms/sample - loss: 0.6374 - accuracy: 0.6277 - val_loss: 0.6347 - val_accuracy: 0.6396
# Epoch 11/50
# 22500/22500 [==============================] - 27s 1ms/sample - loss: 0.6340 - accuracy: 0.6350 - val_loss: 0.6342 - val_accuracy: 0.6408
# Epoch 12/50
# 22500/22500 [==============================] - 27s 1ms/sample - loss: 0.6345 - accuracy: 0.6332 - val_loss: 0.6336 - val_accuracy: 0.6428
# Epoch 13/50
# 22464/22500 [============================>.] - ETA: 0s - loss: 0.6332 - accuracy: 0.6367
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 22500/22500 [==============================] - 27s 1ms/sample - loss: 0.6333 - accuracy: 0.6368 - val_loss: 0.6330 - val_accuracy: 0.6432
# Epoch 00013: early stopping

# %%
plot_history(history)

# %%
roc_auc_score(y_test_vec.values,
              gru_model.predict(test_vecs.astype('float')).reshape(-1))
# Out:
# 0.7086296863999999
